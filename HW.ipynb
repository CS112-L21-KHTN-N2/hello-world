# %% [markdown]
# <a href="https://colab.research.google.com/github/CS112-L21-KHTN-N2/hello-world/blob/readme-edits/HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hello world

# %%
print('Hello world')
# Out:
# Hello world

# %% [markdown]
# Test

# %%
print('123456789')
# Out:
# 123456789
